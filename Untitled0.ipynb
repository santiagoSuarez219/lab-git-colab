# %%
https://github.com/santiagoSuarez219/lab-git-colab.git

# %%
from google.colab import userdata
token = userdata.get('GITHUB_TOKEN')
print("Token cargado:", token[:4] + "..." )  # solo muestra los primeros 4 caracteres
# Out:
# Token cargado: gith...

# %%
nombre = "Prueba de flujo A"
print(f"Hola desde {nombre}")
# Out:
# Hola desde Prueba de flujo A
